# %% [markdown]
# # Arbol elemental con libreria  rpart

# %% [markdown]
# ## Introduccion

# %% [markdown]
# Este es el primer notebook/script de la materia Laboratorio de Implementacion I, se expone en la primera clase.
# <br>Se utilizan Arboles de Decision, librería **rpart**,  el primer algoritmo, el más simple que utilizaremos en la materia pero que es el fundamento de los Ensembles de Arboles de Decision tales como  Random Forest y  Gradient Boosting of Decision Trees (XGBoost/LightGBM)
# <br>La materia posee un dataset con 31 meses, en las primeras clases toda la cohorte, independiente de la modalidad elegida, utilizará **dataset_pequeno** que posee apenas un mes histórico 202107 y obviamente el mes donde se debe realizar la predicción 202109
# <br>Este primer notebook/script **no** desarrolla todas las etapas necesarias para la generación de un buen modelo, apenas posee la parte final del pipeline/workflow.

# %% [markdown]
# ### Limitaciones

# %% [markdown]
# Este primer y elemental notebook/script supone estas simplificaciónes:
# * Solo se dispone del mes 202107 con el campo clase_ternaria completo, es el unico mes donde entrenar
# * Se decidió previamente, de alguna forma, que la etapa de Final Training se hará sobre TODO el dataset de 202107
# * Se obtuvieron previamente los hiperparámetros optimos de la libería **rpart** para este problema, mediante algun tipo de busqueda búsqueda.  Esta es la etapa que demandará decenas de horas para quienes opten por la *modalidad Analista Senior*
# * No se realiza ningun tipo de feature engineering intra-mes
# * Al no disponer de datos históricos no se realiza ningun tipo de feature engineering histórico
# * No hay ningun analisis de la calidad de los campos, no se analiza si ocurrió alguna catástrofe ese mes y algun campo no se calculó correctamente
# * Noy hay ningun tipo de análisis de Data Drifting entre los meses de 202107 y 202109
# * Obedientemente se trabaja utlizando como clase el campo **clase_ternaria** sin ningun tipo de transformacion
#
#
# <br> Obviamente, a lo largo de la materia se avanzará sobre todas las limitacinoes anteriores.

# %% [markdown]
# ## Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo **kaggle.json** al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ## Final Train y generacion de la prediccion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  653308 34.9 1439380    76.9 1117743  59.7
# Vcells 1216786  9.3 8388608    64.0 1924963  14.7

# %% [markdown]
# * Instalacion de la libreria  rpart.plot  para dibujar el arbol
# * invocacion de las librerias  **data.table**  **rpart** y  **rpart.plot**

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")

if (!require("rpart.plot")) install.packages("rpart.plot")
require("rpart.plot")
# Out:
# Loading required package: data.table
#
# Loading required package: rpart
#
# Loading required package: rpart.plot

# %% [markdown]
# Crear y moverse a la carpeta donde se va a trabajar

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "KA2001"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# ## Final Training

# %% [markdown]
# ### Final Train Dataset

# %% [markdown]
# Es importante notar que para el entrenamiento final utilizo el mes de 202107 completo sin ningun tipo particion  train/test, aqui no hay random, aqui no hay semillas

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")
dtrain_final <- dataset[foto_mes == 202107] # defino donde voy a entrenar

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# Aqui los hiperparámetros estan hardcodeados
# <br> Usted puede jugar con ellos manualmente
# <br> En las siguientes clases veremos como encontrar previamente los hiperparámetros óptimos, para ser copiados aquí

# %%
param_final <- list (
  "cp"= -0.144612 , # complejidad minima
  "minsplit"= 752, # minima cantidad de regs en un nodo para hacer el split
  "minbucket"= 365, # minima cantidad de regs en una hoja
  "maxdepth"= 12 # profundidad máxima del arbol
)

# %% [markdown]
# ### Training

# %%
# genero el modelo,  aqui se construye el arbol
# quiero predecir clase_ternaria a partir de el resto de las variables
modelo_final <- rpart(
    formula= "clase_ternaria ~ .",
    data= dtrain_final, # los datos donde voy a entrenar
    xval= 0,
    control= param_final
)

# %% [markdown]
# #### Impresion del modelo

# %%
# grafico el arbol
options(repr.plot.width=30, repr.plot.height=20 )

prp(modelo_final,
    extra= 101,
    digits= -5,
    branch= 1,
    type= 4,
    varlen= 0,
    faclen= 0
)
# Out:
# Warning message:
# “labs do not fit even at cex 0.15, there may be some overplotting”
# plot without title

# %% [markdown]
# ## Dataset Future

# %% [markdown]
# Aqui se define el dataset donde quiero hacer la prediccion final, generalmente esto viene dado por el problema y es trivial su eleccion

# %%
dfuture <- dataset[foto_mes == 202109] # defino donde voy a aplicar el modelo

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo_final a los datos del futuro

# %%
# aplico el modelo a los datos nuevos
prediccion <- predict(
    object= modelo_final,
    newdata= dfuture,
    type= "prob"
)

# veo que  quedó en predccion
# es una matriz, una linea por registro del dataset dfuture
# una columna para cada uno de los valores de la clase
prediccion
# Out:
#        BAJA+1       BAJA+2       CONTINUA
# 1      3.533819e-05 0.0001590218 0.9998056
# 2      3.533819e-05 0.0001590218 0.9998056
# 3      4.489796e-02 0.0448979592 0.9102041
# 4      0.000000e+00 0.0004730369 0.9995270
# 5      0.000000e+00 0.0004730369 0.9995270
# 6      3.533819e-05 0.0001590218 0.9998056
# 7      3.533819e-05 0.0001590218 0.9998056
# 8      0.000000e+00 0.0004730369 0.9995270
# 9      0.000000e+00 0.0004730369 0.9995270
# 10     0.000000e+00 0.0005307856 0.9994692
# 11     3.533819e-05 0.0001590218 0.9998056
# 12     2.739726e-03 0.0000000000 0.9972603
# 13     0.000000e+00 0.0000000000 1.0000000
# 14     0.000000e+00 0.0087912088 0.9912088
# 15     0.000000e+00 0.0053619303 0.9946381
# 16     6.479482e-03 0.0064794816 0.9870410
# 17     3.533819e-05 0.0001590218 0.9998056
# 18     0.000000e+00 0.0004730369 0.9995270
# 19     2.457002e-03 0.0024570025 0.9950860
# 20     3.533819e-05 0.0001590218 0.9998056
# 21     0.000000e+00 0.0004730369 0.9995270
# 22     4.597701e-03 0.0091954023 0.9862069
# 23     3.533819e-05 0.0001590218 0.9998056
# 24     0.000000e+00 0.0000000000 1.0000000
# 25     0.000000e+00 0.0000000000 1.0000000
# 26     0.000000e+00 0.0004730369 0.9995270
# 27     0.000000e+00 0.0004730369 0.9995270
# 28     3.533819e-05 0.0001590218 0.9998056
# 29     2.375297e-03 0.0023752969 0.9952494
# 30     3.533819e-05 0.0001590218 0.9998056
# ⋮      ⋮            ⋮            ⋮
# 165064 0.007052186  0.012693935  0.9802539
# 165065 0.007052186  0.012693935  0.9802539
# 165066 0.007052186  0.012693935  0.9802539
# 165067 0.007052186  0.012693935  0.9802539
# 165068 0.007052186  0.012693935  0.9802539
# 165069 0.007052186  0.012693935  0.9802539
# 165070 0.007052186  0.012693935  0.9802539
# 165071 0.002739726  0.013698630  0.9835616
# 165072 0.007052186  0.012693935  0.9802539
# 165073 0.007052186  0.012693935  0.9802539
# 165074 0.007052186  0.012693935  0.9802539
# 165075 0.007052186  0.012693935  0.9802539
# 165076 0.079831933  0.065126050  0.8550420
# 165077 0.118279570  0.064516129  0.8172043
# 165078 0.007052186  0.012693935  0.9802539
# 165079 0.007052186  0.012693935  0.9802539
# 165080 0.007052186  0.012693935  0.9802539
# 165081 0.007052186  0.012693935  0.9802539
# 165082 0.007052186  0.012693935  0.9802539
# 165083 0.007052186  0.012693935  0.9802539
# 165084 0.000000000  0.001373626  0.9986264
# 165085 0.007052186  0.012693935  0.9802539
# 165086 0.007052186  0.012693935  0.9802539
# 165087 0.007052186  0.012693935  0.9802539
# 165088 0.007052186  0.012693935  0.9802539
# 165089 0.028953229  0.055679287  0.9153675
# 165090 0.002739726  0.002739726  0.9945205
# 165091 0.007052186  0.012693935  0.9802539
# 165092 0.007052186  0.012693935  0.9802539
# 165093 0.007052186  0.012693935  0.9802539

# %% [markdown]
# ## Tabla Prediccion

# %%
tb_prediccion <- as.data.table(list(
  "numero_de_cliente" = dfuture$numero_de_cliente,
  "prob"=prediccion[, "BAJA+2"]
))

# %% [markdown]
# ## Decision

# %%
# decido a quien se envia estimulo y a quien no
# como trabajo con clase_ternaria puedo hacer el corte en 1/40
# solo le envio estimulo a los registros
#  con probabilidad de BAJA+2 mayor  a  1/40

tb_prediccion[, Predicted := prob > (1/40) ]

# veo que hay en tb_prediccion
tb_prediccion
# Out:
#        numero_de_cliente prob         Predicted
# 1      29183733          0.0001590218 FALSE
# 2      29184468          0.0001590218 FALSE
# 3      29185245          0.0448979592  TRUE
# 4      29186441          0.0004730369 FALSE
# 5      29186475          0.0004730369 FALSE
# 6      29187730          0.0001590218 FALSE
# 7      29187764          0.0001590218 FALSE
# 8      29187961          0.0004730369 FALSE
# 9      29189899          0.0004730369 FALSE
# 10     29189993          0.0005307856 FALSE
# 11     29190113          0.0001590218 FALSE
# 12     29192179          0.0000000000 FALSE
# 13     29193101          0.0000000000 FALSE
# 14     29193281          0.0087912088 FALSE
# 15     29193324          0.0053619303 FALSE
# 16     29195356          0.0064794816 FALSE
# 17     29195433          0.0001590218 FALSE
# 18     29196099          0.0004730369 FALSE
# 19     29196902          0.0024570025 FALSE
# 20     29198055          0.0001590218 FALSE
# 21     29198891          0.0004730369 FALSE
# 22     29199242          0.0091954023 FALSE
# 23     29200335          0.0001590218 FALSE
# 24     29200343          0.0000000000 FALSE
# 25     29200514          0.0000000000 FALSE
# 26     29200651          0.0004730369 FALSE
# 27     29200727          0.0004730369 FALSE
# 28     29200770          0.0001590218 FALSE
# 29     29200984          0.0023752969 FALSE
# 30     29201086          0.0001590218 FALSE
# ⋮      ⋮                 ⋮            ⋮
# 165064 187967614         0.012693935  FALSE
# 165065 187969270         0.012693935  FALSE
# 165066 187989740         0.012693935  FALSE
# 165067 187999433         0.012693935  FALSE
# 165068 188009390         0.012693935  FALSE
# 165069 188009578         0.012693935  FALSE
# 165070 188015094         0.012693935  FALSE
# 165071 188017716         0.013698630  FALSE
# 165072 188019279         0.012693935  FALSE
# 165073 188031482         0.012693935  FALSE
# 165074 188042080         0.012693935  FALSE
# 165075 188054394         0.012693935  FALSE
# 165076 188055368         0.065126050   TRUE
# 165077 188057878         0.064516129   TRUE
# 165078 188061679         0.012693935  FALSE
# 165079 188062558         0.012693935  FALSE
# 165080 188064497         0.012693935  FALSE
# 165081 188071815         0.012693935  FALSE
# 165082 188073113         0.012693935  FALSE
# 165083 188074787         0.012693935  FALSE
# 165084 188084847         0.001373626  FALSE
# 165085 188096188         0.012693935  FALSE
# 165086 188097537         0.012693935  FALSE
# 165087 188100654         0.012693935  FALSE
# 165088 188101739         0.012693935  FALSE
# 165089 188115120         0.055679287   TRUE
# 165090 188116871         0.002739726  FALSE
# 165091 188122277         0.012693935  FALSE
# 165092 188128903         0.012693935  FALSE
# 165093 188136205         0.012693935  FALSE

# %% [markdown]
# ## Kaggle

# %%
# genero el archivo para Kaggle
# en el formato requerido por Kaggle
# <numero_de_cliente, Predicted>  separados por coma, estension .csv

archivo_kaggle <- "K101_006.csv"

fwrite( tb_prediccion[, list(numero_de_cliente, Predicted)],
    file = archivo_kaggle,
    sep = ","
)

# %% [markdown]
# ### Kaggle Competition Submit

# %% [markdown]
# Google Colab ya trae instalada una libreria llamada **kaggle** de python, que permite hacer submits a la Plataforma Kaggle

# %%
comando <- "kaggle competitions submit"
competencia <- "-c data-mining-analista-sr-2025-a"
arch <- paste( "-f", archivo_kaggle)

# %%
mensaje <-  paste0( "-m 'cp=", param_final$cp, "  minsplit=", param_final$minsplit, "  minbucket=", param_final$minbucket, "  maxdepth=", param_final$maxdepth, "'")

# %%
linea <- paste( comando, competencia, arch, mensaje)

# este el el comando que correria desde el prompt de Linux
linea
# Out:
# [1] "kaggle competitions submit -c data-mining-analista-sr-2025-a -f K101_006.csv -m 'cp=-0.144612  minsplit=752  minbucket=365  maxdepth=12'"

# %%
# ejecuto el comando
salida <- system(linea, intern=TRUE)
cat(salida)
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A

# %% [markdown]
# ## Tarea para el Hogar

# %% [markdown]
# Explorar manualmente que hiperparámetros genera una mayor ganancia en Kaggle
# <br> Si en un momento logra quedar en primera posición del Private Leaderboard, saquese una selfie
